# %%
from data_sparsity.notebook_helpers import case_paths, run_case
from data_sparsity.utils.viz import (
    draw_storage_schema,
    draw_table,
    format_bytes,
    format_table_value,
    parquet_disk_size,
    plot_grid_case,
)

# %% [markdown]
# ### List of cases - Single variable
#
# 2D because it's easier to understand and visualize
#
# * Purely gridded data, maximum density (minimum sparsity)
# * Purely irregular data
# * Minimum density on a grid
# * Somehow sparse data on a grid
#
# Each case is written to its own folder and rendered as a representative map.

# %% [markdown]
# ### Purely gridded data, 10'000 points in 100x100 grid

# %%
ds, df = run_case(
    "purely_gridded",
    num_obs=10000,
    density=1,
    seed=202607,
    base_dir="./tutorial2",
    title="Purely gridded data",
)

# %% [markdown]
# ### Low density, 100 points on 100x100 grid

# %%
ds, df = run_case(
    "purely_irregular",
    num_obs=100,
    density= 0.01,
    seed=202607,
    base_dir="./tutorial2",
    title="Purely irregular data",
)

# %% [markdown]
# ### Somehow sparse data on a grid, 6 points

# %%
ds, df = run_case(
    "somehow_sparse_grid",
    num_obs=5000,
    density=0.5,
    seed=202607,
    base_dir="./tutorial2",
    title="Somehow sparse data on a grid",
)

# %%
ds, df = run_case(
    "somehow_sparse_grid",
    num_obs=3000,
    density=0.3,
    seed=202607,
    base_dir="./tutorial2",
    title="Somehow sparse data on a grid",
)
